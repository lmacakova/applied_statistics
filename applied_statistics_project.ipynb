# %% [markdown]
# # Analysis of Plant Growth Dataset

# %%
import math as math
import itertools
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import scipy.stats as stats
import statsmodels as sm
import seaborn as sns

# %%
FILENAME= "PlantGrowth.csv"
DATADIR = "../applied_statistics/"

df = pd.read_csv(DATADIR + FILENAME)
df
# Out:
#     rownames  weight group
# 0          1    4.17  ctrl
# 1          2    5.58  ctrl
# 2          3    5.18  ctrl
# 3          4    6.11  ctrl
# 4          5    4.50  ctrl
# 5          6    4.61  ctrl
# 6          7    5.17  ctrl
# 7          8    4.53  ctrl
# 8          9    5.33  ctrl
# 9         10    5.14  ctrl
# 10        11    4.81  trt1
# 11        12    4.17  trt1
# 12        13    4.41  trt1
# 13        14    3.59  trt1
# 14        15    5.87  trt1
# 15        16    3.83  trt1
# 16        17    6.03  trt1
# 17        18    4.89  trt1
# 18        19    4.32  trt1
# 19        20    4.69  trt1
# 20        21    6.31  trt2
# 21        22    5.12  trt2
# 22        23    5.54  trt2
# 23        24    5.50  trt2
# 24        25    5.37  trt2
# 25        26    5.29  trt2
# 26        27    4.92  trt2
# 27        28    6.15  trt2
# 28        29    5.80  trt2
# 29        30    5.26  trt2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rownames  30 non-null     int64
#  1   weight    30 non-null     float64
#  2   group     30 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 852.0+ bytes

# %%
df.describe()
# Out:
#         rownames     weight
# count  30.000000  30.000000
# mean   15.500000   5.073000
# std     8.803408   0.701192
# min     1.000000   3.590000
# 25%     8.250000   4.550000
# 50%    15.500000   5.155000
# 75%    22.750000   5.530000
# max    30.000000   6.310000

# %%
df.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17980\1660334235.py in ?()
# ----> 1 df.unique()
#
# c:\Users\Lucia\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'
